# %%
import pickle
import os

from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder

import xgboost as xgb

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from sklearn.model_selection import TimeSeriesSplit,cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error


import warnings
warnings.filterwarnings('ignore')

# %%
print("Working with these versions of libraries\n")
print("-"*50)
print(f"Numpy version {np.__version__}")
print(f"Pandas version {pd.__version__}")
print(f"XGBoost version {xgb.__version__}")
# Out:
# Working with these versions of libraries
#
# --------------------------------------------------
# Numpy version 1.26.4
# Pandas version 1.5.1
# XGBoost version 1.3.3

# %%
CWD = os.getcwd()
DATA_PATH = os.path.join(CWD, "data")

# DATA_PATH = ""

FILE_NAME = "ts_kaggle_train.csv"
TRAIN_CSV_PATH = os.path.join(DATA_PATH, FILE_NAME)

# %%
df= pd.read_csv((TRAIN_CSV_PATH),index_col=0)

# %%
df.head()
# Out:
#          date unique_id  city_id  shop_id  item_category_id  item_id  \
# 0  2013-01-31  12_11365       16       12                 9    11365
# 1  2013-01-31  12_11369       16       12                 9    11369
# 2  2013-01-31  12_11370       16       12                 9    11370
# 3  2013-01-31  12_11373       16       12                 9    11373
# 4  2013-01-31  12_12231       16       12                49    12231
#
#    monthly_average_price  monthly_sales
# 0            1511.512626           30.0
# 1             572.715278           30.0
# 2             699.776786           30.0
# 3             548.900000            6.0
# 4             350.000000            3.0

# %% [markdown]
# **Objetivo: En base a los meses que disponemos en el dataset, sacar la predicción de 'monthly_sale' del mes que viene.**

# %%
df['date']= pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14484 entries, 0 to 14483
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   14484 non-null  datetime64[ns]
#  1   unique_id              14484 non-null  object
#  2   city_id                14484 non-null  int64
#  3   shop_id                14484 non-null  int64
#  4   item_category_id       14484 non-null  int64
#  5   item_id                14484 non-null  int64
#  6   monthly_average_price  13262 non-null  float64
#  7   monthly_sales          13756 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 1018.4+ KB

# %%
# conocer fechas unicas. 33 para entrenar 1 para predecir
df['date'].nunique()
# Out:
# 34

# %%
# Series temproales únicas
df['unique_id'].nunique()
# Out:
# 426

# %%
df.describe()
# Out:
#             city_id       shop_id  item_category_id       item_id  \
# count  14484.000000  14484.000000      14484.000000  14484.000000
# mean      10.833333     31.967136         39.356808   8626.431925
# std        6.227364     15.236351         20.439654   5905.273346
# min        0.000000      3.000000          2.000000     32.000000
# 25%        7.000000     22.000000         30.000000   4248.000000
# 50%        7.000000     31.000000         35.000000   6457.000000
# 75%       16.000000     44.000000         55.000000  12551.000000
# max       23.000000     59.000000         83.000000  22088.000000
#
#        monthly_average_price  monthly_sales
# count           13262.000000   13756.000000
# mean              916.089314       7.337889
# std               820.945949       7.915032
# min                 4.928571       0.000000
# 25%               299.000000       2.000000
# 50%               649.000000       5.000000
# 75%              1149.000000       9.000000
# max              9305.121212      30.000000

# %%
df.isnull().sum()
# Out:
# date                        0
# unique_id                   0
# city_id                     0
# shop_id                     0
# item_category_id            0
# item_id                     0
# monthly_average_price    1222
# monthly_sales             728
# dtype: int64

# %% [markdown]
# Df de ventas, un caso transaccional. En este caso yo puedo identificar nulos de 2 formas.
# - 1. Si isnull()
# - 2. Si el 'monthly_sales' = 0

# %%
(
    df
    ['monthly_sales']
    .value_counts(dropna= False)
    .sort_index()
    .plot(kind='bar')

)
# Out:
# <Axes: >

# %%
import seaborn as sns
import numpy as np

# %%
pt= (
    df
    .pivot_table(
        index= 'date',
        columns= 'unique_id',
        values= 'monthly_sales',
        aggfunc='sum'
    
    )
    .replace(
        {
            0:np.nan
        }
    
    )
#     .isnull()
    .notnull()
)

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='unique_id', ylabel='date'>

# %% [markdown]
# **Importante esto:** comprobar si mis series temporales estan completas (todos productos y todas las fechas, están todas las combinaciones)
#
# **Por eso chequeo fundamental:**

# %%
df.shape
# Out:
# (14484, 8)

# %%
df['unique_id'].nunique()
# Out:
# 426

# %%
df['date'].nunique()
# Out:
# 34

# %%
426 * 34
# Out:
# 14484

# %% [markdown]
# De partida están todos los registros posible. (14484)

# %% [markdown]
# Aquí tenemos nuestro primer EDA, minicontacto con el dataset. **Pero mi objetivo inicial** es tener un codigo que yo pueda correr de principio a fin, 1 lines(importo dataset), última (predicción)

# %% [markdown]
# Veamos cuales son las fechas min y max de nuestro dataset:

# %%
MIN_DATE= df['date'].min()
MAX_DATE= df['date'].max()

# %%
print (f'Min date is {MIN_DATE}\nMax date is {MAX_DATE}')
# Out:
# Min date is 2013-01-31 00:00:00
# Max date is 2015-10-31 00:00:00

# %%
df.isnull().sum()
# Out:
# date                        0
# unique_id                   0
# city_id                     0
# shop_id                     0
# item_category_id            0
# item_id                     0
# monthly_average_price    1222
# monthly_sales             728
# dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
sample_ts= '31_4249'

# %%
df[df['unique_id']==sample_ts]
# Out:
#            date unique_id  city_id  shop_id  item_category_id  item_id  \
# 5666 2013-01-31   31_4249        7       31                23     4249
# 5743 2013-02-28   31_4249        7       31                23     4249
# 5820 2013-03-31   31_4249        7       31                23     4249
# 5897 2013-04-30   31_4249        7       31                23     4249
# 5974 2013-05-31   31_4249        7       31                23     4249
# 6051 2013-06-30   31_4249        7       31                23     4249
# 6128 2013-07-31   31_4249        7       31                23     4249
# 6205 2013-08-31   31_4249        7       31                23     4249
# 6282 2013-09-30   31_4249        7       31                23     4249
# 6359 2013-10-31   31_4249        7       31                23     4249
# 6436 2013-11-30   31_4249        7       31                23     4249
# 6513 2013-12-31   31_4249        7       31                23     4249
# 6590 2014-01-31   31_4249        7       31                23     4249
# 6667 2014-02-28   31_4249        7       31                23     4249
# 6744 2014-03-31   31_4249        7       31                23     4249
# 6821 2014-04-30   31_4249        7       31                23     4249
# 6898 2014-05-31   31_4249        7       31                23     4249
# 6975 2014-06-30   31_4249        7       31                23     4249
# 7052 2014-07-31   31_4249        7       31                23     4249
# 7129 2014-08-31   31_4249        7       31                23     4249
# 7206 2014-09-30   31_4249        7       31                23     4249
# 7283 2014-10-31   31_4249        7       31                23     4249
# 7360 2014-11-30   31_4249        7       31                23     4249
# 7437 2014-12-31   31_4249        7       31                23     4249
# 7514 2015-01-31   31_4249        7       31                23     4249
# 7591 2015-02-28   31_4249        7       31                23     4249
# 7668 2015-03-31   31_4249        7       31                23     4249
# 7745 2015-04-30   31_4249        7       31                23     4249
# 7822 2015-05-31   31_4249        7       31                23     4249
# 7899 2015-06-30   31_4249        7       31                23     4249
# 7976 2015-07-31   31_4249        7       31                23     4249
# 8053 2015-08-31   31_4249        7       31                23     4249
# 8130 2015-09-30   31_4249        7       31                23     4249
# 8207 2015-10-31   31_4249        7       31                23     4249
#
#       monthly_average_price  monthly_sales
# 5666            1899.000000            2.0
# 5743            1599.000000            5.0
# 5820            1013.416000            6.0
# 5897            1598.900000           10.0
# 5974            1598.937500            8.0
# 6051            1599.000000            4.0
# 6128            1399.000000            4.0
# 6205            1599.000000            2.0
# 6282            1199.000000            5.0
# 6359             929.075000            4.0
# 6436            1199.000000            5.0
# 6513            1199.000000            6.0
# 6590            1199.000000           12.0
# 6667            1199.000000            7.0
# 6744             965.670000           12.0
# 6821             838.800000            3.0
# 6898             839.100000            3.0
# 6975             839.000000            3.0
# 7052                    NaN            0.0
# 7129             930.561667            6.0
# 7206             801.107500            4.0
# 7283            1199.000000            2.0
# 7360             774.281667           10.0
# 7437             698.840303           19.0
# 7514             928.543333            6.0
# 7591             851.603333            7.0
# 7668             898.813333            3.0
# 7745                    NaN            0.0
# 7822                    NaN            0.0
# 7899             884.300000            3.0
# 7976            1135.686667            3.0
# 8053            1347.050000            3.0
# 8130             901.280000            4.0
# 8207                    NaN            NaN

# %%
df.fillna({
    'monthly_sales':0
}, inplace= True)

# %%
df['monthly_average_price']=(
    df.groupby('unique_id',group_keys=False)
    ['monthly_average_price'].apply(
        lambda series: series.interpolate().ffill().bfill()
    )
)

# df['monthly_average_price']=(
#     df.groupby('unique_id',group_keys=False)
#     ['monthly_average_price'].apply(
#         lambda series: series.bfill().ffill()
#     )
# )

# %%
df.sort_values(['unique_id','date'], ascending= True, inplace= True)

# %%
df[df['unique_id']==sample_ts]
# Out:
#            date unique_id  city_id  shop_id  item_category_id  item_id  \
# 5666 2013-01-31   31_4249        7       31                23     4249
# 5743 2013-02-28   31_4249        7       31                23     4249
# 5820 2013-03-31   31_4249        7       31                23     4249
# 5897 2013-04-30   31_4249        7       31                23     4249
# 5974 2013-05-31   31_4249        7       31                23     4249
# 6051 2013-06-30   31_4249        7       31                23     4249
# 6128 2013-07-31   31_4249        7       31                23     4249
# 6205 2013-08-31   31_4249        7       31                23     4249
# 6282 2013-09-30   31_4249        7       31                23     4249
# 6359 2013-10-31   31_4249        7       31                23     4249
# 6436 2013-11-30   31_4249        7       31                23     4249
# 6513 2013-12-31   31_4249        7       31                23     4249
# 6590 2014-01-31   31_4249        7       31                23     4249
# 6667 2014-02-28   31_4249        7       31                23     4249
# 6744 2014-03-31   31_4249        7       31                23     4249
# 6821 2014-04-30   31_4249        7       31                23     4249
# 6898 2014-05-31   31_4249        7       31                23     4249
# 6975 2014-06-30   31_4249        7       31                23     4249
# 7052 2014-07-31   31_4249        7       31                23     4249
# 7129 2014-08-31   31_4249        7       31                23     4249
# 7206 2014-09-30   31_4249        7       31                23     4249
# 7283 2014-10-31   31_4249        7       31                23     4249
# 7360 2014-11-30   31_4249        7       31                23     4249
# 7437 2014-12-31   31_4249        7       31                23     4249
# 7514 2015-01-31   31_4249        7       31                23     4249
# 7591 2015-02-28   31_4249        7       31                23     4249
# 7668 2015-03-31   31_4249        7       31                23     4249
# 7745 2015-04-30   31_4249        7       31                23     4249
# 7822 2015-05-31   31_4249        7       31                23     4249
# 7899 2015-06-30   31_4249        7       31                23     4249
# 7976 2015-07-31   31_4249        7       31                23     4249
# 8053 2015-08-31   31_4249        7       31                23     4249
# 8130 2015-09-30   31_4249        7       31                23     4249
# 8207 2015-10-31   31_4249        7       31                23     4249
#
#       monthly_average_price  monthly_sales
# 5666            1899.000000            2.0
# 5743            1599.000000            5.0
# 5820            1013.416000            6.0
# 5897            1598.900000           10.0
# 5974            1598.937500            8.0
# 6051            1599.000000            4.0
# 6128            1399.000000            4.0
# 6205            1599.000000            2.0
# 6282            1199.000000            5.0
# 6359             929.075000            4.0
# 6436            1199.000000            5.0
# 6513            1199.000000            6.0
# 6590            1199.000000           12.0
# 6667            1199.000000            7.0
# 6744             965.670000           12.0
# 6821             838.800000            3.0
# 6898             839.100000            3.0
# 6975             839.000000            3.0
# 7052             884.780833            0.0
# 7129             930.561667            6.0
# 7206             801.107500            4.0
# 7283            1199.000000            2.0
# 7360             774.281667           10.0
# 7437             698.840303           19.0
# 7514             928.543333            6.0
# 7591             851.603333            7.0
# 7668             898.813333            3.0
# 7745             893.975556            0.0
# 7822             889.137778            0.0
# 7899             884.300000            3.0
# 7976            1135.686667            3.0
# 8053            1347.050000            3.0
# 8130             901.280000            4.0
# 8207             901.280000            0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14484 entries, 0 to 14483
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   14484 non-null  datetime64[ns]
#  1   unique_id              14484 non-null  object
#  2   city_id                14484 non-null  int64
#  3   shop_id                14484 non-null  int64
#  4   item_category_id       14484 non-null  int64
#  5   item_id                14484 non-null  int64
#  6   monthly_average_price  14484 non-null  float64
#  7   monthly_sales          14484 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 1018.4+ KB

# %%
df.isnull().sum()
# Out:
# date                     0
# unique_id                0
# city_id                  0
# shop_id                  0
# item_category_id         0
# item_id                  0
# monthly_average_price    0
# monthly_sales            0
# dtype: int64

# %%
df
# Out:
#             date unique_id  city_id  shop_id  item_category_id  item_id  \
# 0     2013-01-31  12_11365       16       12                 9    11365
# 7     2013-02-28  12_11365       16       12                 9    11365
# 14    2013-03-31  12_11365       16       12                 9    11365
# 21    2013-04-30  12_11365       16       12                 9    11365
# 28    2013-05-31  12_11365       16       12                 9    11365
# ...          ...       ...      ...      ...               ...      ...
# 14435 2015-06-30    7_7893       21        7                 6     7893
# 14447 2015-07-31    7_7893       21        7                 6     7893
# 14459 2015-08-31    7_7893       21        7                 6     7893
# 14471 2015-09-30    7_7893       21        7                 6     7893
# 14483 2015-10-31    7_7893       21        7                 6     7893
#
#        monthly_average_price  monthly_sales
# 0                1511.512626           30.0
# 7                1533.125000           27.0
# 14               3252.470238           30.0
# 21               1590.515152           27.0
# 28               1447.531250           30.0
# ...                      ...            ...
# 14435            2490.000000            1.0
# 14447            2690.000000            1.0
# 14459            2490.000000            1.0
# 14471            2689.900000            5.0
# 14483            2689.900000            0.0
#
# [14484 rows x 8 columns]

# %% [markdown]
# ## **EDA:**
# Vamos al notebook de EDA para ver como son nuestras series temporales y coger ideas para futuras variables

# %% [markdown]
# ### Build Time Series Features (**CORE IDEA**)

# %% [markdown]
# Dado que vamos a tener que iterar muchas veces sobre nuestro dataset, nos interesa tener todo el código encapsulado en funciones para su reutilización.
#
# Uno de los apartados clave será la generación de variables.
#
# Como hemos visto antes, nuestro dataset contiene más de 400 Series Temporales.
#
# Algunas de estas Series Temporales las podemos agrupar para sacar nueva información.
#
# Por ejemplo, podemos construir una variables del estilo:
#
# 1. Las ventas totales por ITEM_ID (la menor granularidad posible).
# 2. Las ganancias totales por ITEM_CATEGORY_ID y SHOP_ID (una granularidad mayor a la 1).
# 3. Las ventas totales por SHOP_ID (una granularidad mayor).
# 4. Y todas las combinaciones que queramos intermedias.

# %%
# ganancias

# mes de forma temporal (sin, cos)
# mes bajo o no

# ventas * item_id
# ganacias* tienda * item_id
# ganancias * tienda


##ACTUALIZAR!!

# %%
df['revenue']=df['monthly_average_price']*df['monthly_sales']

# %%
# Extraer mes
df['month'] = df['date'].dt.month

# Codificar de forma circular
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

# %%
df['is_low_month'] = df['month'].apply(lambda m: 1 if m in [10, 11] else 0)

# %%
df.head()
# Out:
#          date unique_id  city_id  shop_id  item_category_id  item_id  \
# 0  2013-01-31  12_11365       16       12                 9    11365
# 7  2013-02-28  12_11365       16       12                 9    11365
# 14 2013-03-31  12_11365       16       12                 9    11365
# 21 2013-04-30  12_11365       16       12                 9    11365
# 28 2013-05-31  12_11365       16       12                 9    11365
#
#     monthly_average_price  monthly_sales       revenue  month  month_sin  \
# 0             1511.512626           30.0  45345.378788      1   0.500000
# 7             1533.125000           27.0  41394.375000      2   0.866025
# 14            3252.470238           30.0  97574.107143      3   1.000000
# 21            1590.515152           27.0  42943.909091      4   0.866025
# 28            1447.531250           30.0  43425.937500      5   0.500000
#
#        month_cos  is_low_month
# 0   8.660254e-01             0
# 7   5.000000e-01             0
# 14  6.123234e-17             0
# 21 -5.000000e-01             0
# 28 -8.660254e-01             0

# %%
def build_ts_vars(df,target_column, agg_func, agg_func_name, nr_lags, gb_list= None):
    assert 'date' in df.columns, 'Date must be in df columns'
    

    # Nombre base de la variable
    if gb_list:
        new_name = '_'.join(gb_list + [target_column, agg_func_name])
    else:
        new_name = f'global_{target_column}_{agg_func_name}'

    # Agrupación: si hay gb_list, agrupamos; si no, solo resample global
    if gb_list:
        gb_df_ = (
            df
            .set_index('date')
            .groupby(gb_list)
            .resample('M')[target_column]
            .apply(agg_func)
            .to_frame()
            .reset_index()
            .rename(columns={target_column: new_name})
        )
    else:
        gb_df_ = (
            df
            .set_index('date')
            .resample('M')[target_column]
            .apply(agg_func)
            .to_frame(name=new_name)
            .reset_index()
        )

    # Crear lags
    for lag in range(1, nr_lags + 1):
        gb_df_[f'{new_name}_lag{lag}'] = (
            gb_df_
            .groupby(gb_list) if gb_list else gb_df_
        )[new_name].transform(lambda series: series.shift(lag))

    print(f"Dropping columns that might cause target leakage: {new_name}")
    gb_df_.drop(columns=[new_name], inplace=True)

    return gb_df_

# %%
vars_item_id= build_ts_vars(
    df = df,
    gb_list = ['item_id'],
    target_column = 'monthly_sales',
    agg_func = np.sum,
    agg_func_name = 'sum',
    nr_lags = 2

)

vars_shop_item_revenue= build_ts_vars(
    df = df,
    gb_list = ['shop_id','item_id'],
    target_column = 'revenue',
    agg_func = np.sum,
    agg_func_name = 'sum',
    nr_lags = 2

)

vars_shop_id_revenue= build_ts_vars(
    df = df,
    gb_list = ['shop_id'],
    target_column = 'revenue',
    agg_func = np.sum,
    agg_func_name = 'sum',
    nr_lags = 2

)

# vars_shop_id_avg = build_ts_vars(
#     df= df,
#     gb_list = ['shop_id'],
#     target_column= 'monthly_sales',
#     agg_func = np.mean,
#     agg_func_name = 'avg',
#     nr_lags= 2
# )
# Out:
# Dropping columns that might cause target leakage: item_id_monthly_sales_sum
# Dropping columns that might cause target leakage: shop_id_item_id_revenue_sum
# Dropping columns that might cause target leakage: shop_id_revenue_sum

# %%
unique_products_per_shop_month = (
    df[df['monthly_sales'] > 0]
    .groupby(['date', 'shop_id'])['item_id']
    .nunique()
    .reset_index()
    .rename(columns={'item_id': 'unique_products_sold'})
)

# %%
df['revenue_ma_2'] = df['revenue'].shift(1).rolling(window = 2).mean()

# %% [markdown]
# ### Join TS Features

# %% [markdown]
# En este apartado, hacemos el merge del full_df con las variables auxiliares.
#
# Debemos controlar muy bien el merge, para no provocar un cartesiano

# %%
print(df.shape)

df= pd.merge(df, vars_item_id, on = ['date', 'item_id'], how = "left")
df = pd.merge(df, vars_shop_item_revenue, on = ['date', 'shop_id', 'item_id'], how = "left")
df = pd.merge(df, vars_shop_id_revenue, on = ['date', 'shop_id'], how = 'left')
# df = pd.merge(df, vars_shop_id_avg , on = ['date', 'shop_id'], how = 'left')

df = df.merge(unique_products_per_shop_month, on=['date', 'shop_id'], how='left')





print(df.shape)
# Out:
# (14484, 14)
# (14484, 21)

# %% [markdown]
# ### Build New Features FROM Ts features

# %% [markdown]
# # ENTRENAMOS SIEMPRE CON EL PASADO

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#         date unique_id  city_id  shop_id  item_category_id  item_id  \
# 0 2013-01-31  12_11365       16       12                 9    11365
# 1 2013-02-28  12_11365       16       12                 9    11365
# 2 2013-03-31  12_11365       16       12                 9    11365
# 3 2013-04-30  12_11365       16       12                 9    11365
# 4 2013-05-31  12_11365       16       12                 9    11365
#
#    monthly_average_price  monthly_sales       revenue  month  month_sin  \
# 0            1511.512626           30.0  45345.378788      1   0.500000
# 1            1533.125000           27.0  41394.375000      2   0.866025
# 2            3252.470238           30.0  97574.107143      3   1.000000
# 3            1590.515152           27.0  42943.909091      4   0.866025
# 4            1447.531250           30.0  43425.937500      5   0.500000
#
#       month_cos  is_low_month  revenue_ma_2  item_id_monthly_sales_sum_lag1  \
# 0  8.660254e-01             0           NaN                             NaN
# 1  5.000000e-01             0           NaN                            30.0
# 2  6.123234e-17             0  43369.876894                            27.0
# 3 -5.000000e-01             0  69484.241071                            30.0
# 4 -8.660254e-01             0  70259.008117                            27.0
#
#    item_id_monthly_sales_sum_lag2  shop_id_item_id_revenue_sum_lag1  \
# 0                             NaN                               NaN
# 1                             NaN                      45345.378788
# 2                            30.0                      41394.375000
# 3                            27.0                      97574.107143
# 4                            30.0                      42943.909091
#
#    shop_id_item_id_revenue_sum_lag2  shop_id_revenue_sum_lag1  \
# 0                               NaN                       NaN
# 1                               NaN             213263.540693
# 2                      45345.378788             236417.673786
# 3                      41394.375000             271836.568071
# 4                      97574.107143             231494.439542
#
#    shop_id_revenue_sum_lag2  unique_products_sold
# 0                       NaN                   7.0
# 1                       NaN                   7.0
# 2             213263.540693                   7.0
# 3             236417.673786                   7.0
# 4             271836.568071                   7.0

# %% [markdown]
# ### Train Test Split

# %%
df.columns.tolist()
# Out:
# ['date',
#  'unique_id',
#  'city_id',
#  'shop_id',
#  'item_category_id',
#  'item_id',
#  'monthly_average_price',
#  'monthly_sales',
#  'revenue',
#  'month',
#  'month_sin',
#  'month_cos',
#  'is_low_month',
#  'revenue_ma_2',
#  'item_id_monthly_sales_sum_lag1',
#  'item_id_monthly_sales_sum_lag2',
#  'shop_id_item_id_revenue_sum_lag1',
#  'shop_id_item_id_revenue_sum_lag2',
#  'shop_id_revenue_sum_lag1',
#  'shop_id_revenue_sum_lag2',
#  'unique_products_sold']

# %%
COLUMNS_TO_DROP = [
    'revenue',
    'monthly_sales',
    'date',
    'month'
]

# %%
df.set_index("unique_id", inplace = True)

# %%
df.sample(5)
# Out:
#                 date  city_id  shop_id  item_category_id  item_id  \
# unique_id
# 22_13100  2014-12-31        7       22                73    13100
# 25_1249   2013-03-31        7       25                55     1249
# 57_2252   2014-05-31       22       57                30     2252
# 19_5822   2015-08-31        6       19                35     5822
# 28_5823   2014-10-31        7       28                35     5823
#
#            monthly_average_price  monthly_sales  revenue  month     month_sin  \
# unique_id
# 22_13100                  1350.0            1.0   1350.0     12 -2.449294e-16
# 25_1249                    299.0           11.0   3289.0      3  1.000000e+00
# 57_2252                    479.0            3.0   1437.0      5  5.000000e-01
# 19_5822                   1149.0            9.0  10341.0      8 -8.660254e-01
# 28_5823                   2599.0           16.0  41584.0     10 -8.660254e-01
#
#               month_cos  is_low_month  revenue_ma_2  \
# unique_id
# 22_13100   1.000000e+00             0        5400.0
# 25_1249    6.123234e-17             0        4485.0
# 57_2252   -8.660254e-01             0        2096.5
# 19_5822   -5.000000e-01             0       12639.0
# 28_5823    5.000000e-01             1       38985.0
#
#            item_id_monthly_sales_sum_lag1  item_id_monthly_sales_sum_lag2  \
# unique_id
# 22_13100                              2.0                             6.0
# 25_1249                              11.0                            19.0
# 57_2252                              29.0                            43.0
# 19_5822                             186.0                           216.0
# 28_5823                             147.0                           144.0
#
#            shop_id_item_id_revenue_sum_lag1  shop_id_item_id_revenue_sum_lag2  \
# unique_id
# 22_13100                             2700.0                            8100.0
# 25_1249                              3289.0                            5681.0
# 57_2252                              1198.0                            2995.0
# 19_5822                             16086.0                            9192.0
# 28_5823                             38985.0                           38985.0
#
#            shop_id_revenue_sum_lag1  shop_id_revenue_sum_lag2  \
# unique_id
# 22_13100              113458.590632             125845.389209
# 25_1249               241798.345238             212663.307500
# 57_2252               118803.162063             139322.216333
# 19_5822                56551.125000              44338.500000
# 28_5823               165205.011250             221463.855833
#
#            unique_products_sold
# unique_id
# 22_13100                   16.0
# 25_1249                    35.0
# 57_2252                    21.0
# 19_5822                    14.0
# 28_5823                    28.0

# %%
train_index = sorted(list(df['date'].unique()))[:-2] # todos meses menos 2 últimos

valid_index = [sorted(list(df['date'].unique()))[-2]] # últimos 2 meses

test_index = [sorted(list(df['date'].unique()))[-1]] # último mes

# %%
train_index
# Out:
# [numpy.datetime64('2013-01-31T00:00:00.000000000'),
#  numpy.datetime64('2013-02-28T00:00:00.000000000'),
#  numpy.datetime64('2013-03-31T00:00:00.000000000'),
#  numpy.datetime64('2013-04-30T00:00:00.000000000'),
#  numpy.datetime64('2013-05-31T00:00:00.000000000'),
#  numpy.datetime64('2013-06-30T00:00:00.000000000'),
#  numpy.datetime64('2013-07-31T00:00:00.000000000'),
#  numpy.datetime64('2013-08-31T00:00:00.000000000'),
#  numpy.datetime64('2013-09-30T00:00:00.000000000'),
#  numpy.datetime64('2013-10-31T00:00:00.000000000'),
#  numpy.datetime64('2013-11-30T00:00:00.000000000'),
#  numpy.datetime64('2013-12-31T00:00:00.000000000'),
#  numpy.datetime64('2014-01-31T00:00:00.000000000'),
#  numpy.datetime64('2014-02-28T00:00:00.000000000'),
#  numpy.datetime64('2014-03-31T00:00:00.000000000'),
#  numpy.datetime64('2014-04-30T00:00:00.000000000'),
#  numpy.datetime64('2014-05-31T00:00:00.000000000'),
#  numpy.datetime64('2014-06-30T00:00:00.000000000'),
#  numpy.datetime64('2014-07-31T00:00:00.000000000'),
#  numpy.datetime64('2014-08-31T00:00:00.000000000'),
#  numpy.datetime64('2014-09-30T00:00:00.000000000'),
#  numpy.datetime64('2014-10-31T00:00:00.000000000'),
#  numpy.datetime64('2014-11-30T00:00:00.000000000'),
#  numpy.datetime64('2014-12-31T00:00:00.000000000'),
#  numpy.datetime64('2015-01-31T00:00:00.000000000'),
#  numpy.datetime64('2015-02-28T00:00:00.000000000'),
#  numpy.datetime64('2015-03-31T00:00:00.000000000'),
#  numpy.datetime64('2015-04-30T00:00:00.000000000'),
#  numpy.datetime64('2015-05-31T00:00:00.000000000'),
#  numpy.datetime64('2015-06-30T00:00:00.000000000'),
#  numpy.datetime64('2015-07-31T00:00:00.000000000'),
#  numpy.datetime64('2015-08-31T00:00:00.000000000')]

# %%
X_train = (
    df[
    df['date']
    .isin(train_index)
    ]
    .drop(COLUMNS_TO_DROP, axis= 1)
)
Y_train = (
    df[
    df['date']
    .isin(train_index)
    ]
    ['monthly_sales']
)


X_valid = (
    df[
    df['date']
    .isin(valid_index)
    ]
    .drop(COLUMNS_TO_DROP, axis= 1)
)
Y_valid = (
    df[
    df['date']
    .isin(valid_index)
    ]
    ['monthly_sales']
)


X_test = (
    df[
    df['date']
    .isin(test_index)
    ]
    .drop(COLUMNS_TO_DROP, axis= 1)
)
Y_test = (
    df[
    df['date']
    .isin(test_index)
    ]
    ['monthly_sales']
)

# %%
X_train.head()
# Out:
#            city_id  shop_id  item_category_id  item_id  monthly_average_price  \
# unique_id
# 12_11365        16       12                 9    11365            1511.512626
# 12_11365        16       12                 9    11365            1533.125000
# 12_11365        16       12                 9    11365            3252.470238
# 12_11365        16       12                 9    11365            1590.515152
# 12_11365        16       12                 9    11365            1447.531250
#
#            month_sin     month_cos  is_low_month  revenue_ma_2  \
# unique_id
# 12_11365    0.500000  8.660254e-01             0           NaN
# 12_11365    0.866025  5.000000e-01             0           NaN
# 12_11365    1.000000  6.123234e-17             0  43369.876894
# 12_11365    0.866025 -5.000000e-01             0  69484.241071
# 12_11365    0.500000 -8.660254e-01             0  70259.008117
#
#            item_id_monthly_sales_sum_lag1  item_id_monthly_sales_sum_lag2  \
# unique_id
# 12_11365                              NaN                             NaN
# 12_11365                             30.0                             NaN
# 12_11365                             27.0                            30.0
# 12_11365                             30.0                            27.0
# 12_11365                             27.0                            30.0
#
#            shop_id_item_id_revenue_sum_lag1  shop_id_item_id_revenue_sum_lag2  \
# unique_id
# 12_11365                                NaN                               NaN
# 12_11365                       45345.378788                               NaN
# 12_11365                       41394.375000                      45345.378788
# 12_11365                       97574.107143                      41394.375000
# 12_11365                       42943.909091                      97574.107143
#
#            shop_id_revenue_sum_lag1  shop_id_revenue_sum_lag2  \
# unique_id
# 12_11365                        NaN                       NaN
# 12_11365              213263.540693                       NaN
# 12_11365              236417.673786             213263.540693
# 12_11365              271836.568071             236417.673786
# 12_11365              231494.439542             271836.568071
#
#            unique_products_sold
# unique_id
# 12_11365                    7.0
# 12_11365                    7.0
# 12_11365                    7.0
# 12_11365                    7.0
# 12_11365                    7.0

# %%
Y_train.head()
# Out:
# unique_id
# 12_11365    30.0
# 12_11365    27.0
# 12_11365    30.0
# 12_11365    27.0
# 12_11365    30.0
# Name: monthly_sales, dtype: float64

# %%
X_valid.head()
# Out:
#            city_id  shop_id  item_category_id  item_id  monthly_average_price  \
# unique_id
# 12_11365        16       12                 9    11365             995.680556
# 12_11369        16       12                 9    11369            1321.367605
# 12_11370        16       12                 9    11370             681.715341
# 12_11373        16       12                 9    11373             437.929115
# 12_12231        16       12                49    12231             350.000000
#
#            month_sin     month_cos  is_low_month  revenue_ma_2  \
# unique_id
# 12_11365        -1.0 -1.836970e-16             0  15573.892857
# 12_11369        -1.0 -1.836970e-16             0  23102.088095
# 12_11370        -1.0 -1.836970e-16             0  17427.053072
# 12_11373        -1.0 -1.836970e-16             0  11910.100461
# 12_12231        -1.0 -1.836970e-16             0    525.000000
#
#            item_id_monthly_sales_sum_lag1  item_id_monthly_sales_sum_lag2  \
# unique_id
# 12_11365                             13.0                             6.0
# 12_11369                             21.0                            30.0
# 12_11370                             30.0                            30.0
# 12_11373                             30.0                            30.0
# 12_12231                              2.0                             1.0
#
#            shop_id_item_id_revenue_sum_lag1  shop_id_item_id_revenue_sum_lag2  \
# unique_id
# 12_11365                       24312.785714                       6835.000000
# 12_11369                       21881.300000                      24322.876190
# 12_11370                       22540.892857                      12313.213287
# 12_11373                       15125.323129                       8694.877792
# 12_12231                         700.000000                        350.000000
#
#            shop_id_revenue_sum_lag1  shop_id_revenue_sum_lag2  \
# unique_id
# 12_11365              110960.301701              69015.967269
# 12_11369              110960.301701              69015.967269
# 12_11370              110960.301701              69015.967269
# 12_11373              110960.301701              69015.967269
# 12_12231              110960.301701              69015.967269
#
#            unique_products_sold
# unique_id
# 12_11365                    7.0
# 12_11369                    7.0
# 12_11370                    7.0
# 12_11373                    7.0
# 12_12231                    7.0

# %%
Y_valid.head()
# Out:
# unique_id
# 12_11365    21.0
# 12_11369    30.0
# 12_11370    30.0
# 12_11373    30.0
# 12_12231     2.0
# Name: monthly_sales, dtype: float64

# %%
print(X_train.shape, X_valid.shape)
print(X_train.columns)
print(Y_train.describe(), Y_valid.describe())
# Out:
# (13632, 16) (426, 16)
# Index(['city_id', 'shop_id', 'item_category_id', 'item_id',
#        'monthly_average_price', 'month_sin', 'month_cos', 'is_low_month',
#        'revenue_ma_2', 'item_id_monthly_sales_sum_lag1',
#        'item_id_monthly_sales_sum_lag2', 'shop_id_item_id_revenue_sum_lag1',
#        'shop_id_item_id_revenue_sum_lag2', 'shop_id_revenue_sum_lag1',
#        'shop_id_revenue_sum_lag2', 'unique_products_sold'],
#       dtype='object')
# count    13632.000000
# mean         7.226086
# std          7.912928
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          9.000000
# max         30.000000
# Name: monthly_sales, dtype: float64 count    426.000000
# mean       5.713615
# std        7.386643
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        6.000000
# max       30.000000
# Name: monthly_sales, dtype: float64

# %% [markdown]
# ### Model Train

# %%
# max_depth
# n_estimators
# early_stopping_rounds

model = xgb.XGBRegressor(max_depth = 5, eval_metric = "rmse", seed = 175)

model.fit(
    X_train,
    Y_train,
    eval_set = [(X_train, Y_train), (X_valid, Y_valid)],
    verbose = True,
    # early_stopping_rounds=10

)
# Out:
# [0]	validation_0-rmse:7.99385	validation_1-rmse:6.68469
# [1]	validation_0-rmse:6.45200	validation_1-rmse:5.14780
# [2]	validation_0-rmse:5.46936	validation_1-rmse:4.22884
# [3]	validation_0-rmse:4.86863	validation_1-rmse:3.72775
# [4]	validation_0-rmse:4.51451	validation_1-rmse:3.39340
# [5]	validation_0-rmse:4.30873	validation_1-rmse:3.24791
# [6]	validation_0-rmse:4.10420	validation_1-rmse:3.11870
# [7]	validation_0-rmse:3.99881	validation_1-rmse:3.07681
# [8]	validation_0-rmse:3.89619	validation_1-rmse:3.05727
# [9]	validation_0-rmse:3.82016	validation_1-rmse:3.02150
# [10]	validation_0-rmse:3.75213	validation_1-rmse:2.99247
# [11]	validation_0-rmse:3.72384	validation_1-rmse:2.99191
# [12]	validation_0-rmse:3.68516	validation_1-rmse:3.00237
# [13]	validation_0-rmse:3.64754	validation_1-rmse:2.98545
# [14]	validation_0-rmse:3.59676	validation_1-rmse:2.97196
# [15]	validation_0-rmse:3.56157	validation_1-rmse:2.97163
# [16]	validation_0-rmse:3.53751	validation_1-rmse:2.97165
# [17]	validation_0-rmse:3.51984	validation_1-rmse:2.95965
# [18]	validation_0-rmse:3.49490	validation_1-rmse:2.95517
# [19]	validation_0-rmse:3.47268	validation_1-rmse:2.92359
# [20]	validation_0-rmse:3.45209	validation_1-rmse:2.91353
# [21]	validation_0-rmse:3.44193	validation_1-rmse:2.91255
# [22]	validation_0-rmse:3.42200	validation_1-rmse:2.89881
# [23]	validation_0-rmse:3.41149	validation_1-rmse:2.89952
# [24]	validation_0-rmse:3.39074	validation_1-rmse:2.90714
# [25]	validation_0-rmse:3.37362	validation_1-rmse:2.90089
# [26]	validation_0-rmse:3.34772	validation_1-rmse:2.90332
# [27]	validation_0-rmse:3.32715	validation_1-rmse:2.90048
# [28]	validation_0-rmse:3.32067	validation_1-rmse:2.89412
# [29]	validation_0-rmse:3.30120	validation_1-rmse:2.89138
# [30]	validation_0-rmse:3.28190	validation_1-rmse:2.88569
# [31]	validation_0-rmse:3.26926	validation_1-rmse:2.88591
# [32]	validation_0-rmse:3.25729	validation_1-rmse:2.87906
# [33]	validation_0-rmse:3.24543	validation_1-rmse:2.87647
# [34]	validation_0-rmse:3.23585	validation_1-rmse:2.88096
# [35]	validation_0-rmse:3.23052	validation_1-rmse:2.87934
# [36]	validation_0-rmse:3.21481	validation_1-rmse:2.88296
# [37]	validation_0-rmse:3.20208	validation_1-rmse:2.88154
# [38]	validation_0-rmse:3.18513	validation_1-rmse:2.87269
# [39]	validation_0-rmse:3.16981	validation_1-rmse:2.86889
# [40]	validation_0-rmse:3.15485	validation_1-rmse:2.86408
# [41]	validation_0-rmse:3.13360	validation_1-rmse:2.85841
# [42]	validation_0-rmse:3.11775	validation_1-rmse:2.85021
# [43]	validation_0-rmse:3.10345	validation_1-rmse:2.85609
# [44]	validation_0-rmse:3.09434	validation_1-rmse:2.87624
# [45]	validation_0-rmse:3.08463	validation_1-rmse:2.87713
# [46]	validation_0-rmse:3.07995	validation_1-rmse:2.87701
# [47]	validation_0-rmse:3.07115	validation_1-rmse:2.87633
# [48]	validation_0-rmse:3.05893	validation_1-rmse:2.87780
# [49]	validation_0-rmse:3.04883	validation_1-rmse:2.86804
# [50]	validation_0-rmse:3.03372	validation_1-rmse:2.86373
# [51]	validation_0-rmse:3.02235	validation_1-rmse:2.85970
# [52]	validation_0-rmse:3.01284	validation_1-rmse:2.85680
# [53]	validation_0-rmse:3.01066	validation_1-rmse:2.85693
# [54]	validation_0-rmse:2.98961	validation_1-rmse:2.86174
# [55]	validation_0-rmse:2.98112	validation_1-rmse:2.87174
# [56]	validation_0-rmse:2.97235	validation_1-rmse:2.87099
# [57]	validation_0-rmse:2.96289	validation_1-rmse:2.87155
# [58]	validation_0-rmse:2.95535	validation_1-rmse:2.87472
# [59]	validation_0-rmse:2.94795	validation_1-rmse:2.87365
# [60]	validation_0-rmse:2.93369	validation_1-rmse:2.87425
# [61]	validation_0-rmse:2.92049	validation_1-rmse:2.87507
# [62]	validation_0-rmse:2.90946	validation_1-rmse:2.87498
# [63]	validation_0-rmse:2.90143	validation_1-rmse:2.87374
# [64]	validation_0-rmse:2.89556	validation_1-rmse:2.87453
# [65]	validation_0-rmse:2.88589	validation_1-rmse:2.87195
# [66]	validation_0-rmse:2.87600	validation_1-rmse:2.87350
# [67]	validation_0-rmse:2.86952	validation_1-rmse:2.86921
# [68]	validation_0-rmse:2.86286	validation_1-rmse:2.87959
# [69]	validation_0-rmse:2.85555	validation_1-rmse:2.87548
# [70]	validation_0-rmse:2.84294	validation_1-rmse:2.88454
# [71]	validation_0-rmse:2.83507	validation_1-rmse:2.90331
# [72]	validation_0-rmse:2.82808	validation_1-rmse:2.90024
# [73]	validation_0-rmse:2.81724	validation_1-rmse:2.90416
# [74]	validation_0-rmse:2.80966	validation_1-rmse:2.90620
# [75]	validation_0-rmse:2.80089	validation_1-rmse:2.90397
# [76]	validation_0-rmse:2.79465	validation_1-rmse:2.91112
# [77]	validation_0-rmse:2.78553	validation_1-rmse:2.91569
# [78]	validation_0-rmse:2.77533	validation_1-rmse:2.90888
# [79]	validation_0-rmse:2.76909	validation_1-rmse:2.90169
# [80]	validation_0-rmse:2.76475	validation_1-rmse:2.89851
# [81]	validation_0-rmse:2.75495	validation_1-rmse:2.89835
# [82]	validation_0-rmse:2.74263	validation_1-rmse:2.89654
# [83]	validation_0-rmse:2.73447	validation_1-rmse:2.89980
# [84]	validation_0-rmse:2.72851	validation_1-rmse:2.89797
# [85]	validation_0-rmse:2.72577	validation_1-rmse:2.89797
# [86]	validation_0-rmse:2.71534	validation_1-rmse:2.89913
# [87]	validation_0-rmse:2.70647	validation_1-rmse:2.90771
# [88]	validation_0-rmse:2.69640	validation_1-rmse:2.90438
# [89]	validation_0-rmse:2.68359	validation_1-rmse:2.90399
# [90]	validation_0-rmse:2.67453	validation_1-rmse:2.90453
# [91]	validation_0-rmse:2.66566	validation_1-rmse:2.91380
# [92]	validation_0-rmse:2.65323	validation_1-rmse:2.91057
# [93]	validation_0-rmse:2.64697	validation_1-rmse:2.90891
# [94]	validation_0-rmse:2.64472	validation_1-rmse:2.90822
# [95]	validation_0-rmse:2.63700	validation_1-rmse:2.91228
# [96]	validation_0-rmse:2.62947	validation_1-rmse:2.91033
# [97]	validation_0-rmse:2.62130	validation_1-rmse:2.90800
# [98]	validation_0-rmse:2.61427	validation_1-rmse:2.90946
# [99]	validation_0-rmse:2.60754	validation_1-rmse:2.91595
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='rmse',
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=18,
#              num_parallel_tree=1, random_state=175, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, seed=175, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Model Evaluation (**CORE IDEA**)

# %%
fig, ax = plt.subplots(figsize = (10, 15))
xgb.plot_importance(model, importance_type = "gain", ax = ax);

# %%
Y_train_predict = model.predict(X_train)
Y_valid_predict = model.predict(X_valid)

rmse_train = np.sqrt(
    mean_squared_error(
        y_true = Y_train,
        y_pred = Y_train_predict
    )
)

rmse_valid = np.sqrt(
    mean_squared_error(
        y_true = Y_valid,
        y_pred = Y_valid_predict
    )
)

rmse_train= str(round(rmse_train, 3)).replace(".", "_")
rmse_valid = str(round(rmse_valid, 3)).replace(".", "_")

# %%
print(f"Train RMSE: {rmse_train}")
print(f"Validation RMSE: {rmse_valid}")
# Out:
# Train RMSE: 2_608
# Validation RMSE: 2_916

# %% [markdown]
# ### Retrain Model
#
# Reentrenamos el modelo con los datos de X_train y X_valid

# %%
X_full_train = pd.concat([X_train, X_valid])
Y_full_train = pd.concat([Y_train, Y_valid])

model.fit(X_full_train, Y_full_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, eval_metric='rmse',
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=5, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=18,
#              num_parallel_tree=1, random_state=175, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, seed=175, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Prediction
#
# En este apartado vamos a utilizar el modelo entrenado para hacer una predicción y posteriormente enviar el submit a Kaggle.

# %%
if "monthly_sales" in X_test.columns:
    X_test.drop("monthly_sales", axis = 1, inplace = True)
    
Y_test_predict = model.predict(X_test)
X_test["monthly_sales"] = Y_test_predict

# %%
X_test.reset_index(inplace = True)

# %%
# distribución del sumbit
plt.hist(X_test['monthly_sales'], bins=50)
plt.show()

# %%
monthly_sales_min = X_test['monthly_sales'].min()
monthly_sales_max = X_test['monthly_sales'].max()

print(f'valor min: {monthly_sales_min}')
print(f'valor max: {monthly_sales_max}')
# Out:
# valor min: -2.8204970359802246
# valor max: 27.0681209564209

# %%
# Obtener fecha y hora actuales en formato deseado
timestamp = datetime.now().strftime("%m-%d_%H-%M")

(
    X_test[["unique_id", "monthly_sales"]]
    .to_csv(f"subm_{timestamp}_train_{rmse_train}_valida_{rmse_valid}.csv", index = False)
)

# %%
print('CUANDO ESTES CONTENTO CON LA ELECCIÓN SUBIR EL NOTEBOOK A NUCLIO (EDA + MODELO)')
# Out:
# CUANDO ESTES CONTENTO CON LA ELECCIÓN SUBIR EL NOTEBOOK A NUCLIO (EDA + MODELO)
